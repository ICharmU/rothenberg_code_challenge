# %% [markdown]
# # Exploratory Analysis

# %%
# Todo :
# cleaning for as much data as you can get. 
# really dig deep into the SEC facts you can use 
# and how they are related to either years or quarters.
