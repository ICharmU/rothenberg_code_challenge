# %% [markdown]
# # Combining Cleaned Data
#
# All data to be combined will have a unique year identifier

# %% [markdown]
# **TODO**:
# * Clean datasets
# * Combine datasets
# * Consider splitting in quarterly and annual figures
# * Should be able to perform EDA on the combined dataset once preprocessing is complete
